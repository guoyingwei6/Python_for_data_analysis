# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#6.1-读写文本格式的数据" data-toc-modified-id="6.1-读写文本格式的数据-1">6.1 读写文本格式的数据</a></span></li></ul></div>

# %% [markdown]
# # 第 6 章 数据加载、存储与文件格式

# %% [markdown]
# ## 6.1 读写文本格式的数据

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[4:, 2] = np.nan
df
# Out:
#           0         1         2
# 0  1.139778  1.497484  1.279504
# 1  1.218240  0.528104  1.002138
# 2 -0.206716 -0.220524 -0.884701
# 3 -0.096759  1.093026 -0.503178
# 4  0.432093  0.798980       NaN
# 5  0.149424  1.353066       NaN

# %%
_ = df.fillna(0, inplace=True)

# %%
_

# %%
df
# Out:
#           0         1         2
# 0  1.139778  1.497484  1.279504
# 1  1.218240  0.528104  1.002138
# 2 -0.206716 -0.220524 -0.884701
# 3 -0.096759  1.093026 -0.503178
# 4  0.432093  0.798980  0.000000
# 5  0.149424  1.353066  0.000000
